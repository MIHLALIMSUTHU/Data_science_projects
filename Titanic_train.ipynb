# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

train = pd.read_csv('train.csv')

# %% [markdown]
# 1. Display Top 5 Rows of The Dataset

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# 2. Check the Last 3 Rows of The Dataset

# %%
train.tail(3)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
# 3. Find Shape of Our Dataset (Number of Rows & Number of Columns)

# %%
train.shape
print('Number of columns is:', train.shape[1])
print('Number of rows is:', train.shape[0])
# Out:
# Number of columns is: 12
# Number of rows is: 891

# %% [markdown]
# 4. Get Information About Our Dataset Like Total Number Rows, Total Number of columns, datatypes of each column and memory requirement

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# Data Filtering

# %%
train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
sum(train['Sex']=='male')
# Number of male passengers that were traveling.
# Out:
# 577

# %%
train[train['Sex']=='male'].head()
#Actual details of the first 5 male passengers.
# Out:
#    PassengerId  Survived  Pclass                            Name   Sex   Age  \
# 0            1         0       3         Braund, Mr. Owen Harris  male  22.0
# 4            5         0       3        Allen, Mr. William Henry  male  35.0
# 5            6         0       3                Moran, Mr. James  male   NaN
# 6            7         0       1         McCarthy, Mr. Timothy J  male  54.0
# 7            8         0       3  Palsson, Master. Gosta Leonard  male   2.0
#
#    SibSp  Parch     Ticket     Fare Cabin Embarked
# 0      1      0  A/5 21171   7.2500   NaN        S
# 4      0      0     373450   8.0500   NaN        S
# 5      0      0     330877   8.4583   NaN        Q
# 6      0      0      17463  51.8625   E46        S
# 7      3      1     349909  21.0750   NaN        S

# %%
#Filtering by number of survived persons.
sum(train['Survived']==1)
# Out:
# 342

# %% [markdown]
# 5. Get Overall Statistics About The Dataframe

# %%
train.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass                 Name   Sex  \
# count    891.000000  891.000000  891.000000                  891   891
# unique          NaN         NaN         NaN                  891     2
# top             NaN         NaN         NaN  Dooley, Mr. Patrick  male
# freq            NaN         NaN         NaN                    1   577
# mean     446.000000    0.383838    2.308642                  NaN   NaN
# std      257.353842    0.486592    0.836071                  NaN   NaN
# min        1.000000    0.000000    1.000000                  NaN   NaN
# 25%      223.500000    0.000000    2.000000                  NaN   NaN
# 50%      446.000000    0.000000    3.000000                  NaN   NaN
# 75%      668.500000    1.000000    3.000000                  NaN   NaN
# max      891.000000    1.000000    3.000000                  NaN   NaN
#
#                Age       SibSp       Parch  Ticket        Fare Cabin Embarked
# ...

# %% [markdown]
# 7.Check Null Values In The Dataset

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
sns.heatmap(train.isnull())
# Out:
# <Axes: >

# %%
#Percentage of null values
per_null = train.isnull().sum() * 100 / len(train)
per_null
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin          77.104377
# Embarked        0.224467
# dtype: float64

# %% [markdown]
# 8. Drop the columns

# %%
train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# 9. Handle missing values

# %%
train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
train['Embarked'].mode()
# Out:
# 0    S
# Name: Embarked, dtype: object

# %%
train['Embarked'].fillna('S', inplace=True)
# Out:
# /tmp/ipython-input-1021043716.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train['Embarked'].fillna('S', inplace=True)

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
 train['Age'].fillna(train['Age'].mean())==train['Age']
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 886     True
# 887     True
# 888    False
# 889     True
# 890     True
# Name: Age, Length: 891, dtype: bool

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %% [markdown]
# 10. Categorical data encoding( Encoding for the 'sex' column)

# %%
train['Sex_encoded']= train['Sex'].map({'male':1, 'female':0})

# %%
train.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked  Sex_encoded
# 0      0  A/5 21171  7.25   NaN        S            1

# %%
x = train['Sex'].map({'male':1, 'female':0})

# %%
train.insert(5, 'New_gender', x)

# %%
train.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex  New_gender  \
# 0            1         0       3  Braund, Mr. Owen Harris  male           1
#
#     Age  SibSp  Parch     Ticket  Fare Cabin Embarked  Sex_encoded
# 0  22.0      1      0  A/5 21171  7.25   NaN        S            1

# %%
#Categorical encoding the 'Embarked' column.
train['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q'], dtype=object)

# %%
New_data = pd.get_dummies(train, columns=['Embarked'], drop_first=True)

# %%
print("Original 'Embarked' column from 'train' dataset:")
display(train[['Embarked']].head())

print("Encoded 'Embarked' columns from 'New_data' dataset showing boolean values:")
display(New_data[['Embarked_Q', 'Embarked_S']].head(10))
# Out:
# Original 'Embarked' column from 'train' dataset:
#   Embarked
# 0        S
# 1        C
# 2        S
# 3        S
# 4        S
# Encoded 'Embarked' columns from 'New_data' dataset showing boolean values:
#    Embarked_Q  Embarked_S
# 0       False        True
# 1       False       False
# 2       False        True
# 3       False        True
# 4       False        True
# 5        True       False
# 6       False        True
# 7       False        True
# 8       False        True
# 9       False       False

# %%
New_data.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex  New_gender  \
# 0            1         0       3  Braund, Mr. Owen Harris  male           1
#
#     Age  SibSp  Parch     Ticket  Fare Cabin  Sex_encoded  Embarked_Q  \
# 0  22.0      1      0  A/5 21171  7.25   NaN            1       False
#
#    Embarked_S
# 0        True

# %% [markdown]
# 11. What is Univariate Analysis?

# %%
train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'New_gender', 'Age',
#        'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'Sex_encoded'],
#       dtype='object')

# %%
train['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %% [markdown]
# 12. How Many People Survived And How Many Died?

# %%
sns.countplot(x='Survived', data=train, palette='pastel')
plt.show()
# Out:
# /tmp/ipython-input-3532551368.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Survived', data=train, palette='pastel')

# %% [markdown]
# 13. How Many Passengers Were In First Class, Second Class, and Third Class?

# %%
train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'New_gender', 'Age',
#        'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'Sex_encoded'],
#       dtype='object')

# %%
train['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
sns.countplot(x='Pclass', data=train, palette='pastel')
# Out:
# /tmp/ipython-input-4167775052.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Pclass', data=train, palette='pastel')
# <Axes: xlabel='Pclass', ylabel='count'>

# %% [markdown]
# 14. Number of Male And Female Passengers

# %%
train['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
sns.countplot(x='Sex', data=train, palette='pastel')
# Out:
# /tmp/ipython-input-3005445561.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Sex', data=train, palette='pastel')
# <Axes: xlabel='Sex', ylabel='count'>

# %%
#Univariate analysis on age column(tsaking two columns at a time and doing an analysis).
plt.hist(train['Age'])
# Out:
# (array([ 54.,  46., 177., 169., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %%
sns.scatterplot(x='Pclass', y='Fare', hue='Survived', data=train)
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %% [markdown]
# 15. Who Has Better Chance of Survival Male or Female?

# %%
train.groupby('Sex')['Survived'].mean()*100
# Out:
# Sex
# female    74.203822
# male      18.890815
# Name: Survived, dtype: float64

# %%
#Visualization of the survival rate
sns.barplot(x='Sex', y='Survived', data=train, palette='pastel')
# Out:
# /tmp/ipython-input-683264039.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Sex', y='Survived', data=train, palette='pastel')
# <Axes: xlabel='Sex', ylabel='Survived'>

# %% [markdown]
# 16. Which Passenger Class Has Better Chance of Survival (First, Second, Or Third Class)?

# %%
train.groupby('Pclass')['Survived'].mean()*100
# Out:
# Pclass
# 1    62.962963
# 2    47.282609
# 3    24.236253
# Name: Survived, dtype: float64

# %%
sns.barplot(x='Pclass', y='Survived', data=train, palette='pastel')
# Out:
# /tmp/ipython-input-842654164.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Pclass', y='Survived', data=train, palette='pastel')
# <Axes: xlabel='Pclass', ylabel='Survived'>

# %% [markdown]
# 17. Feature Engineering

# %%
train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'New_gender', 'Age',
#        'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'Sex_encoded'],
#       dtype='object')

# %%
train['Family_size']=train['SibSp'] + train['Parch']
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  New_gender  \
# 0                            Braund, Mr. Owen Harris    male           1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female           0
# 2                             Heikkinen, Miss. Laina  female           0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female           0
# 4                           Allen, Mr. William Henry    male           1
#
#     Age  SibSp  Parch            Ticket     Fare Cabin Embarked  Sex_encoded  \
# 0  22.0      1      0         A/5 21171   7.2500   NaN        S            1
# 1  38.0      1      0          PC 17599  71.2833   C85        C            0
# 2  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S            0
# ...

# %%
#Fare per person
train['Fare_per_person']=train['Fare']/(train['Family_size']+1)
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  New_gender  \
# 0                            Braund, Mr. Owen Harris    male           1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female           0
# 2                             Heikkinen, Miss. Laina  female           0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female           0
# 4                           Allen, Mr. William Henry    male           1
#
#     Age  SibSp  Parch            Ticket     Fare Cabin Embarked  Sex_encoded  \
# 0  22.0      1      0         A/5 21171   7.2500   NaN        S            1
# 1  38.0      1      0          PC 17599  71.2833   C85        C            0
# 2  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S            0
# ...
